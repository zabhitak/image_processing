# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open('RGB_Matte.png')

# %%
pil
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x480 at 0x1FB517447C8>

# %%
arr = np.array(pil)
arr.shape
# Out:
# (480, 640, 3)

# %%
red = arr[:,:,0]
plt.imshow(red)

# %%
green = arr[100:200, :300]
plt.imshow(green)
